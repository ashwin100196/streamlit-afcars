# %%
import pandas as pd
import streamlit as st
import altair as alt
from geopy.geocoders import GoogleV3
import folium
import numpy as np
from utils import get_filtered_counts, mapped_colors, races
import geopandas as gpd

# %%
gdf = gpd.read_file('TOWNSSURVEY_POLY.shp')
gdf
# Out:
#                TOWN  TOWN_ID  POP1980  POP1990  POP2000  POPCH90_00 TYPE  \
# 0          WESTPORT      334    13861    13852    14183         331    T
# 1          FALMOUTH       96    25007    27960    32660        4700    T
# 2          WESTPORT      334    13861    13852    14183         331    T
# 3          FALMOUTH       96    25007    27960    32660        4700    T
# 4         DARTMOUTH       72    24840    27244    30666        3422    T
# ...             ...      ...      ...      ...      ...         ...  ...
# 1234         NAHANT      196     3922     3828     3632        -196    T
# 1235  NEW BRAINTREE      202      682      881      927          46    T
# 1236        EASTHAM       86     3890     4462     5453         991    T
# 1237        ANDOVER        9    27203    29151    31247        2096    T
# 1238         MARION      169     4027     4496     5123         627    T
#
#       ISLAND COASTAL_PO  FOURCOLOR  ...  FIPS_MCD FIPS_COUNT      ACRES  \
# 0          1         NO          1  ...  25005100          5      0.942
# 1          1         NO          2  ...  25001035          1      3.695
# 2          1         NO          1  ...  25005100          5      0.433
# 3          1         NO          2  ...  25001035          1      0.157
# 4          1         NO          4  ...  25005020          5      0.260
# ...      ...        ...        ...  ...       ...        ...        ...
# 1234       1         NO          2  ...  25009105          9      0.950
# 1235       0         NO          3  ...  25027155         27  13387.175
# 1236       1         NO          4  ...  25001030          1      0.293
# 1237       0        YES          3  ...  25009010          9    207.189
# 1238       1         NO          4  ...  25023070         23      2.388
#
#       SQUARE_MIL  POP2010  POPCH00_10  POPCH80_90    SHAPE_AREA     SHAPE_LEN  \
# 0          0.002    15532        1349          -9  3.810934e+03    310.959400
# 1          0.006    31531       -1129        2953  1.495345e+04    498.058255
# 2          0.001    15532        1349          -9  1.753456e+03    278.276059
# 3          0.000    31531       -1129        2953  6.358812e+02    109.461733
# 4          0.000    34032        3366        2404  1.053604e+03    131.624579
# ...          ...      ...         ...         ...           ...           ...
# 1234       0.002     3410        -222         -94  3.843179e+03    321.605460
# 1235      20.917      999          72         199  5.417596e+07  42901.962904
# 1236       0.001     4956        -497         572  1.184125e+03    140.564687
# 1237       0.324    33201        1954        1948  8.384623e+05  18518.700347
# 1238       0.004     4907        -216         469  9.664744e+03    666.816427
#
#                                                geometry
# 0     POLYGON ((236386.252 808384.495, 236380.123 80...
# 1     POLYGON ((268360.782 808386.365, 268347.943 80...
# 2     POLYGON ((233335.013 809394.755, 233340.333 80...
# 3     POLYGON ((277887.593 814023.755, 277886.782 81...
# 4     POLYGON ((245000.002 815602.875, 245003.153 81...
# ...                                                 ...
# 1234  POLYGON ((248661.193 907368.815, 248657.083 90...
# 1235  POLYGON ((149542.763 900839.425, 155382.932 89...
# 1236  POLYGON ((324154.633 840811.065, 324154.002 84...
# 1237  POLYGON ((225495.502 938455.005, 225513.203 93...
# 1238  POLYGON ((261679.593 825526.185, 261682.333 82...
#
# [1239 rows x 23 columns]

# %%
geometry_column = "geometry"

# %%
gdf['latitude'] = gdf.centroid.y
gdf['longitude'] = gdf.centroid.x
